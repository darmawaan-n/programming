# %%
import pandas as pd
import numpy as np
import pyarrow.parquet as pq
from sqlalchemy import create_engine

# %%
# data = "https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-01.parquet"

data_tps = "https://github.com/reedho/pemilu2024/blob/main/ppwp_tps__001.parquet?raw=true"

# df = pq.read_table(data)
# df = pd.read_parquet(data)
df_tps = pd.read_parquet(data_tps)

# %%
df_tps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125285 entries, 0 to 125284
# Data columns (total 42 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   kode                 125285 non-null  object
#  1   provinsi_kode        125285 non-null  object
#  2   kabupaten_kota_kode  125285 non-null  object
#  3   kecamatan_kode       125285 non-null  object
#  4   kelurahan_desa_kode  125285 non-null  object
#  5   tps                  125285 non-null  object
#  6   suara_paslon_1       21781 non-null   float64
#  7   suara_paslon_2       21780 non-null   float64
#  8   suara_paslon_3       21779 non-null   float64
#  9   chasil_hal_1         53651 non-null   object
#  10  chasil_hal_2         47810 non-null   object
#  11  chasil_hal_3         47789 non-null   object
#  12  suara_sah            12936 non-null   float64
#  13  suara_total          12929 non-null   float64
# ...

# %%
df_tps
# Out:
#                  kode provinsi_kode kabupaten_kota_kode kecamatan_kode  \
# 0       1671181001041            16                1671         167118
# 1       1671181001033            16                1671         167118
# 2       7326042006003            73                7326         732604
# 3       1271101006008            12                1271         127110
# 4       1271101006029            12                1271         127110
# ...               ...           ...                 ...            ...
# 125280  7413101008002            74                7413         741310
# 125281  7312062004006            73                7312         731206
# 125282  7312062004008            73                7312         731206
# 125283  7312062004007            73                7312         731206
# 125284  7373031001010            73                7373         737303
#
#        kelurahan_desa_kode  tps  suara_paslon_1  suara_paslon_2  \
# ...

# %%
df_tps[
    (df_tps["provinsi_nama"] == "BANTEN")
    & (df_tps["kabupaten_kota_nama"] == "KOTA SERANG")
    & (~df_tps["suara_paslon_1"].isna())
    & (~df_tps["suara_paslon_2"].isna())
    & (~df_tps["suara_paslon_3"].isna())
    ]
# Out:
#                 kode provinsi_kode kabupaten_kota_kode kecamatan_kode  \
# 20128  3673061001020            36                3673         367306
# 20152  3673061001002            36                3673         367306
# 20222  3673061001013            36                3673         367306
# 20245  3673061001007            36                3673         367306
# 20288  3673061006014            36                3673         367306
# 20309  3673061001019            36                3673         367306
# 20320  3673061001008            36                3673         367306
# 20365  3673061001014            36                3673         367306
# 20378  3673061001010            36                3673         367306
# 20391  3673061001004            36                3673         367306
# 20430  3673061001009            36                3673         367306
# 20457  3673031008017            36                3673         367303
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1369769 entries, 0 to 1369768
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   VendorID               1369769 non-null  int64
#  1   tpep_pickup_datetime   1369769 non-null  datetime64[us]
#  2   tpep_dropoff_datetime  1369769 non-null  datetime64[us]
#  3   passenger_count        1271417 non-null  float64
#  4   trip_distance          1369769 non-null  float64
#  5   RatecodeID             1271417 non-null  float64
#  6   store_and_fwd_flag     1271417 non-null  object
#  7   PULocationID           1369769 non-null  int64
#  8   DOLocationID           1369769 non-null  int64
#  9   payment_type           1369769 non-null  int64
#  10  fare_amount            1369769 non-null  float64
#  11  extra                  1369769 non-null  float64
#  12  mta_tax                1369769 non-null  float64
# ...

# %%
# This will create an engine, an instant that can be used if we want to communicate with our database
# The explanation is this:
#     postgresql  = the name of RDBMS which we will use
#     (1st) root  = username 
#     (2nd) root  = password 
#     localhost   = host in which our DB reside
#     5432        = port of our DB
#     ny_taxi     = the name of the DB Schema

engine = create_engine("postgresql://root:root@localhost:5432/ny_taxi")

engine.connect()

# %%
# Generate SQL Schema based on dataframe
sql_ddl_schema = pd.io.sql.get_schema(df, "yellow_taxi_data", con=engine)

print(sql_ddl_schema)
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count FLOAT(53),
# 	trip_distance FLOAT(53),
# 	"RatecodeID" FLOAT(53),
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53),
# 	airport_fee FLOAT(53)
# )

# %%
df_chunk = np.array_split(df, 20)
# Out:
# /home/darmawaan_n/.pyenv/versions/3.10.7/lib/python3.10/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %%
# len(df_chunk[12])

# df.head(0).to_sql(name="yellow_taxi_data", con=engine, if_exists='replace')
# Out:
# 0

# %%
# If we want to compute time consumed by each execution
from time import time

# %%
# Let's create a loop where we can insert data by the size of its chunk

for i in range(len(df_chunk)):
    t_start = time()

    df_chunk[i].to_sql(name="yellow_taxi_data", con=engine, if_exists="append")

    t_end = time()

    print(f"Successfully inserted another chunk! It took {(t_end - t_start):.4f} seconds...")
# Out:
# Successfully inserted another chunk! It took 7.7958 seconds...
# Successfully inserted another chunk! It took 6.5685 seconds...
# Successfully inserted another chunk! It took 6.2350 seconds...
# Successfully inserted another chunk! It took 6.2555 seconds...
# Successfully inserted another chunk! It took 6.2533 seconds...
# Successfully inserted another chunk! It took 6.3879 seconds...
# Successfully inserted another chunk! It took 6.1142 seconds...
# Successfully inserted another chunk! It took 6.2334 seconds...
# Successfully inserted another chunk! It took 6.0129 seconds...
# Successfully inserted another chunk! It took 6.2365 seconds...
# Successfully inserted another chunk! It took 6.0378 seconds...
# Successfully inserted another chunk! It took 5.9571 seconds...
# Successfully inserted another chunk! It took 6.0357 seconds...
# Successfully inserted another chunk! It took 5.9775 seconds...
# Successfully inserted another chunk! It took 6.3368 seconds...
# ...

# %%
# Testing if our data has been ingested into DB

qry = '''
SELECT *
FROM yellow_taxi_data
LIMIT 100
'''

pd.read_sql(qry, con=engine)
# Out:
#     index  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0       0         1  2021-01-01 00:30:10   2021-01-01 00:36:12
# 1       1         1  2021-01-01 00:51:20   2021-01-01 00:52:19
# 2       2         1  2021-01-01 00:43:30   2021-01-01 01:11:06
# 3       3         1  2021-01-01 00:15:48   2021-01-01 00:31:01
# 4       4         2  2021-01-01 00:31:49   2021-01-01 00:48:21
# ..    ...       ...                  ...                   ...
# 95     95         2  2021-01-01 00:12:41   2021-01-01 00:26:47
# 96     96         2  2021-01-01 00:23:29   2021-01-01 00:35:03
# 97     97         2  2021-01-01 00:46:17   2021-01-01 00:54:25
# 98     98         2  2021-01-01 00:28:16   2021-01-01 00:51:44
# 99     99         2  2021-01-01 00:42:35   2021-01-01 00:54:41
#
#     passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0               1.0           2.10         1.0                  N
# 1               1.0           0.20         1.0                  N
# ...
